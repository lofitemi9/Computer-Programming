# %% [markdown]
# <h1 style="color: white;">String Manipulation</h1>

# %% [markdown]
# <h2 style="color: teal;">OOP - Object Oriented Programming</h2>
#
# <h4 style="color: lightyellow;">Attributes: </h4>
#
# State - is information about an object
# Behaviour - the behaviour acts upon the state of an object
#
# Class - the class is used to instatantiate(this means create) objects
#
# Object:
# MUST HAVE
#
# - State
# - Behaviour

# %% [markdown]
# ---
#
# <h2 style="color: teal;">Escape Characters</h2>
#
# - \' - Single Quote
# - \" - Double Quote
# - \t - Tab
# - \n - Newline
# - \\\ - Backslash

# %% [markdown]
# ---
#
# <h2 style="color: teal;">Indexing and Slicing Strings</h2>
#
# - print testword[0:5] - This prints out indexes in 'testWord' from 0 to 4 (5 is not included)
# - print testWord[6:] - This prints out indexes after 6

# %% [markdown]
# ---
#
# <h2 style="color: teal;">Immutable</h2>
#
# ### STRINGS ARE IMMUTABLE
#
# This means a string CANNOT be changed

# %% [markdown]
# ---
#
# <h2 style="color: teal;">String Methods</h2>
#
# - isalpha() - Checks if Variable consists of only letters and no blank space
# - isalnum() - Checks if variable consists of letters and numbers and no blank space
# - istitle() -
# -
#
# ---
#
# ---
#
# - startswith() - this checks what the first letter of a variable is
# - endswith() - this checks what the last letter opf a variable is
#
# ---
#
# - rjust(value) - this pushes the variable to the middle according to the value passed (inclusive of the length of the variable)
#   e.g
#
# ---
#
# - strip(value) - this returns a string without any whitespace | whatever string value is passed is stripped
# - lstrip() - this is the same thing but it only strips the first of the value from the left
# - rstrip() - same thing but strips from the right
#
# ---
#
# - split() - this method is called on a string and returns a LIST of strings based upon whitespace

# %% [markdown]
# ---
#
# <h1 style="color: white;">IN-CLASS LAB</h1>
#
# Using only what we have studied to date in the lecture slides, write a function that takes one string argument. The purpose of the function is to identify the frequency of all the vowels in the string and to print out a report using appropriate python formatting techniques previously studied outlining the count of each word vowel and locations. Once the report is complete return 0(zero to the caller)

# %%
# Name : Temiloluwa Shokunbi
# Student Number : 200632787
# Date : 26/09/2025
# Time : 1:20PM
# Brief description of the code : This is a program that finds the amount of vowels 
  #in a word and prints the locations





#I am defining the function 'stringArg' that takes an argument 
def stringArg(word):
  vowelCount = 0
  #this goes through each of the letters in the word and checks if any of the words 
  #match the list
  for i in range(wordLength):
    if (word[i] in ["a", "e", "i", "o", "u"]):
      #this add to the count if a match is found
      vowelCount = vowelCount+1
      locations = i
      #this just uses the 'vowelCount' function as a count and prints out where
      #each vowel is
      print("The location of vowel ", vowelCount,  "is index: " + str(locations))

  
  
  #this prints the amount of the vowels after the function is completed
  print("The Number of vowels in the word is: " + str(vowelCount))
  #print("The locations are " + word)

#this is my argument

word = input("Give me a word: ")
wordLength = len(word)
stringArg(word)
# Out:
# The location of vowel  1 is index: 10
# The location of vowel  2 is index: 11
# The Number of vowels in the word is: 2

# %%
stringArg = input("Word: ")

for i in range(len(stringArg)):
    if "ab" in stringArg[i:i+2]:
        print(stringArg[i:i+2])
# Out:
# ab
# ab
# ab
# ab
