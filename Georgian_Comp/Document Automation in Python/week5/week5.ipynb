# %% [markdown]
# <h2 style="color: teal;">List Methods</h2>

# %% [markdown]
# <h2 style="color: teal;">2-Dimensional Arrays</h2>

# %% [markdown]
# ---
#
# <h1 style="color: white;">IN-CLASS LAB</h1>
#
# Using only what we have studied in the lecture slides to date, write a function that will take a list argument of at least 5 words. The purpose of the function is to identify the location of the first two leters in the first string of the list in all other strings in the list. For each string that contains the two letters (anywhere in the string) print that string and the coordinates of the letters in the list within the list
